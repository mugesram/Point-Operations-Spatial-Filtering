# %% [markdown]
# <a href="https://colab.research.google.com/github/mugesram/Point-Operations-Spatial-Filtering/blob/main/Assignment_1_vision.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# indensity transformation

# %%
import cv2 as cv
import matplotlib.pyplot as plt
import numpy as np

# %%
# Reading Image
image = cv.imread("/content/drive/MyDrive/Vision/Assignment-1/emma.jpg")

fix,ax = plt.subplots(1,1,figsize=(5,8))
ax.imshow(cv.cvtColor(image,cv.COLOR_BGR2RGB))
ax.xaxis.set_ticks_position('top')
ax.yaxis.set_ticks_position('left')
plt.show()

# %%
# Making transform function
t1 = np.linspace(0,50,51)
t2 = np.linspace(100,255,101)
t3 = np.linspace(150,255,106)
t1[-1] = (t1[-1] + t2[0])/2
t2 = np.delete(t2,0)
t2[-1] = (t2[-1] + t3[0])/2
t3 = np.delete(t3,0)
transform = np.concatenate((t1, t2), axis=0).astype('uint8')
transform = np.concatenate((transform, t3), axis=0).astype('uint8')
print(len(transform))
fig,ax = plt.subplots()
ax.plot(transform)
ax.set_xlabel(r'Input, $f(\mathbf{x})$')
ax.set_ylabel('Output, $\mathrm{T}[f(\mathbf{x})]$')
ax.set_xlim(0,255)
ax.set_ylim(0,255)
ax.set_aspect('equal')
plt.show()
# Out:
# 256

# %%
# implementing transformation
transformed_image = cv.LUT(image, transform)

fig, ax = plt.subplots(1, 2, figsize=(12, 8))
ax[0].imshow(image)
ax[0].set_title('Original Image')
ax[1].imshow(transformed_image)
ax[1].set_title('Transformed Image')
for a in ax:
    a.axis('off')
plt.show()
